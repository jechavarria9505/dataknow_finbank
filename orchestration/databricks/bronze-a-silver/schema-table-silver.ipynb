# %%
# %sql
CREATE SCHEMA silver_dev.sql_finbank
MANAGED LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/';

CREATE SCHEMA silver_dev.errores_tables
MANAGED LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/';
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# com.databricks.backend.common.rpc.SparkDriverExceptions$SQLExecutionException: org.apache.spark.sql.catalyst.analysis.NamespaceAlreadyExistsException: [SCHEMA_ALREADY_EXISTS] Cannot create schema `sql_finbank` because it already exists.
# Choose a different name, drop the existing schema, or add the IF NOT EXISTS clause to tolerate pre-existing schema.
# 	at org.apache.spark.sql.errors.QueryCompilationErrors$.namespaceAlreadyExistsError(QueryCompilationErrors.scala:1582)
# 	at org.apache.spark.sql.execution.datasources.v2.CreateNamespaceExec.run(CreateNamespaceExec.scala:53)
# ...

# %%
# %sql
-- =========================
-- SILVER EXTERNAL TABLES
-- =========================

CREATE TABLE IF NOT EXISTS silver_dev.sql_finbank.tb_clientes_core
USING DELTA
LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/sql_finbank/tb_clientes_core';

CREATE TABLE IF NOT EXISTS silver_dev.sql_finbank.tb_mov_financieros
USING DELTA
LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/sql_finbank/tb_mov_financieros';

CREATE TABLE IF NOT EXISTS silver_dev.sql_finbank.tb_obligaciones
USING DELTA
LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/sql_finbank/tb_obligaciones';

CREATE TABLE IF NOT EXISTS silver_dev.sql_finbank.tb_comisiones_log
USING DELTA
LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/sql_finbank/tb_comisiones_log';

CREATE TABLE IF NOT EXISTS silver_dev.sql_finbank.tb_productos_cat
USING DELTA
LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/sql_finbank/tb_productos_cat';

CREATE TABLE IF NOT EXISTS silver_dev.sql_finbank.tb_sucursales_red
USING DELTA
LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/sql_finbank/tb_sucursales_red';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE TABLE IF NOT EXISTS silver_dev.errores_tables.tb_clientes_core
USING DELTA
LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/errores_tables/tb_clientes_core';

CREATE TABLE IF NOT EXISTS silver_dev.errores_tables.tb_mov_financieros
USING DELTA
LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/errores_tables/tb_mov_financieros';

CREATE TABLE IF NOT EXISTS silver_dev.errores_tables.tb_obligaciones
USING DELTA
LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/errores_tables/tb_obligaciones';

CREATE TABLE IF NOT EXISTS silver_dev.errores_tables.tb_comisiones_log
USING DELTA
LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/errores_tables/tb_comisiones_log';

CREATE TABLE IF NOT EXISTS silver_dev.errores_tables.tb_productos_cat
USING DELTA
LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/errores_tables/tb_productos_cat';

CREATE TABLE IF NOT EXISTS silver_dev.errores_tables.tb_sucursales_red
USING DELTA
LOCATION 'abfss://silver@stfinbankdata.dfs.core.windows.net/errores_tables/tb_sucursales_red';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
